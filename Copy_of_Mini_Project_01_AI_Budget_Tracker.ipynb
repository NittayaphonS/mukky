# %% [markdown]
# <a href="https://colab.research.google.com/github/NittayaphonS/mukky/blob/main/Copy_of_Mini_Project_01_AI_Budget_Tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mini Project 01: AI-Powered Budget Tracker
# # ISYS2001 Introduction to Business Programming
#
# **Instructions:**
# 1. Save a copy of this notebook to your Google Drive (File > Save a copy in Drive)
# 2. Rename it to include your name: `Week1_Budget_Tracker_[YourName]`
# 3. Complete all sections and code cells
# 4. Document your AI interactions as you go

# %% [markdown]
# ## Part 1: Environment Setup and First Steps

# %%
# Run this cell to test your environment
print("🎉 Welcome to ISYS2001: Introduction to Business Programming!")
print("📊 Project: Personal Finance Assistant")
print("🤖 Today's Goal: Build a Simple Budget Tracker with AI Help")

# Import datetime to timestamp your work
from datetime import datetime
print(f"\n📅 Worksheet started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# 🎉 Welcome to ISYS2001: Introduction to Business Programming!
# 📊 Project: Personal Finance Assistant
# 🤖 Today's Goal: Build a Simple Budget Tracker with AI Help
#
# 📅 Worksheet started at: 2026-03-25 10:50:56

# %% [markdown]
# ## Part 2: Your First AI Prompt
#
# Use an AI assistant (Gemini in Colab, ChatGPT, or GitHub Copilot) to create a program that:
# - Asks the user for their name
# - Asks for their monthly income
# - Prints a personalized welcome message
#
# ### 📝 Document Your AI Prompt Below:

# %%
# TASK: Write your AI prompt as a comment below
"""
My AI Prompt:
[Create a python program code by ask the user for their name, monthly income and Prints a personalized welcome messaget]
"""

# Paste the AI-generated code below:
# [def main():
    # Ask for user's name
    name = input("What is your name? ")

    # Ask for monthly income
    monthly_income = float(input("What is your monthly income? $"))

    # Print personalized welcome message
    print("\n" + "="*50)
    print(f"Welcome, {name}!")
    print("="*50)
    print(f"Your monthly income: ${monthly_income:,.2f}")
    print("="*50 + "\n")

if __name__ == "__main__":
    main()]
# Out:
#   File "/tmp/ipykernel_2237/3747620424.py", line 10
#     name = input("What is your name? ")
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ### 🔍 Evidence Package Entry #1

# %%
# Evidence Package Documentation
evidence_1 = {
    "timestamp": datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
    "context": "I wanted to create a simple input/output program to practice AI prompting",
    "ai_tool_used": "Gemini/ChatGPT/Copilot",  # Update this
    "what_worked": "The AI understood my request and provided all my need",
    "what_didnt": "I had to understand the code by myself",
    "what_i_learned": "I learned that specific prompts make ai generated everything clearly"
}

# Display your evidence
print("📋 EVIDENCE PACKAGE #1")
for key, value in evidence_1.items():
    print(f"{key}: {value}")
# Out:
# 📋 EVIDENCE PACKAGE #1
# timestamp: 2026-03-25 10:52:42
# context: I wanted to create a simple input/output program to practice AI prompting
# ai_tool_used: Gemini/ChatGPT/Copilot
# what_worked: The AI understood my request and provided all my need
# what_didnt: I had to understand the code by myself
# what_i_learned: I learned that specific prompts make ai generated everything clearly

# %% [markdown]
# ## Part 3: Building the Budget Tracker
#
# Use AI to help you write a program that:
# - Allows users to input their monthly income
# - Allows users to input up to 3 expenses
# - Calculates remaining budget
# - Shows a warning if budget is negative
#
# ### 💡 Pro Tip: Be specific about requirements!

# %%
# TASK: Write your detailed prompt for the budget tracker
"""
My Budget Tracker Prompt:
[Requirements:
1. The program should ask the user to enter their monthly income.
2. The program should allow the user to enter up to 3 expenses.
3. Each expense should be entered separately.
4. The program should calculate the total expenses.
5. The program should calculate the remaining budget by subtracting total expenses from income.
6. Display the remaining budget clearly.
7. If the remaining budget is negative, show a warning message such as "Warning: Your budget is negative!"

The program should be simple and beginner-friendly.]
"""

# %% [markdown]
# ### Paste and Test Your AI-Generated Budget Tracker

# %%
# AI-GENERATED BUDGET TRACKER CODE
# [def main():
print("="*50)
print("     WELCOME TO BUDGET TRACKER")
print("="*50)
print()

    # Step 1: Ask for monthly income
    while True:
        try:
            monthly_income = float(input("Enter your monthly income: $"))
            if monthly_income < 0:
                print("Income cannot be negative. Please try again.")
                continue
            break
        except ValueError:
            print("Invalid input. Please enter a valid number.")

    print()

    # Step 2: Ask for up to 3 expenses
    expenses = []
    print("Enter your expenses (up to 3):")
    print("-" * 50)

    for i in range(3):
        while True:
            try:
                expense_name = input(f"\nExpense {i+1} name (or press Enter to skip): ").strip()

                # Allow user to skip entering more expenses
                if expense_name == "":
                    print(f"Skipping expense {i+1}")
                    break

                expense_amount = float(input(f"Enter amount for {expense_name}: $"))

                if expense_amount < 0:
                    print("Expense amount cannot be negative. Please try again.")
                    continue

                expenses.append({
                    "name": expense_name,
                    "amount": expense_amount
                })
                print(f"✓ {expense_name}: ${expense_amount:.2f} added")
                break

            except ValueError:
                print("Invalid input. Please enter a valid number.")

    print()
    print("="*50)

    # Step 3: Calculate total expenses
    total_expenses = sum(expense["amount"] for expense in expenses)

    # Step 4: Calculate remaining budget
    remaining_budget = monthly_income - total_expenses

    # Step 5: Display summary
    print("     BUDGET SUMMARY")
    print("="*50)
    print(f"Monthly Income:      ${monthly_income:>10,.2f}")
    print("-" * 50)

    # Display individual expenses
    if expenses:
        print("Expenses:")
        for expense in expenses:
            print(f"  • {expense['name']:<20} ${expense['amount']:>10,.2f}")
        print("-" * 50)

    print(f"Total Expenses:      ${total_expenses:>10,.2f}")
    print("="*50)
    print(f"Remaining Budget:    ${remaining_budget:>10,.2f}")
    print("="*50)

    # Step 6: Display warning if budget is negative
    print()
    if remaining_budget < 0:
        print("⚠️  WARNING: Your budget is negative!")
        print(f"    You are over budget by ${abs(remaining_budget):,.2f}")
    else:
        print("✓ Your budget is balanced!")

    print()

if __name__ == "__main__":
      main()
# Out:
#   File "/tmp/ipykernel_2237/969111056.py", line 9
#     while True:
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ### 🐛 Debugging and Refinement

# %%
# Document any issues and fixes
issues_found = [
    "Issue 1: [I entered a word instead of a number and the program stopped working.]",
    "Fix 1: [I made sure to enter numbers for income and expenses.]",
    "Issue 2: [# [def main(): is commented out instead of being actual code.]",
    "Fix 2: [remove #.]",
    # Add more as needed
]

print("🔧 DEBUGGING NOTES:")
for item in issues_found:
    print(f"- {item}")
# Out:
# 🔧 DEBUGGING NOTES:
# - Issue 1: [I entered a word instead of a number and the program stopped working.]
# - Fix 1: [I made sure to enter numbers for income and expenses.]
# - Issue 2: [# [def main(): is commented out instead of being actual code.]
# - Fix 2: [remove #.]

# %%
# REFINED VERSION - Your Working Budget Tracker
# [paste the correct code here]
def main():
    print("="*50)
    print("     WELCOME TO BUDGET TRACKER")
    print("="*50)
    print()

    # Step 1: Ask for monthly income
    while True:
        try:
            monthly_income = float(input("Enter your monthly income: $"))
            if monthly_income < 0:
                print("Income cannot be negative. Please try again.")
                continue
            break
        except ValueError:
            print("Invalid input. Please enter a valid number.")

    print()

    # Step 2: Ask for up to 3 expenses
    expenses = []
    print("Enter your expenses (up to 3):")
    print("-" * 50)

    for i in range(3):
        while True:
            try:
                expense_name = input(f"\nExpense {i+1} name (or press Enter to skip): ").strip()

                # Allow user to skip entering more expenses
                if expense_name == "":
                    print(f"Skipping expense {i+1}")
                    break

                expense_amount = float(input(f"Enter amount for {expense_name}: $"))

                if expense_amount < 0:
                    print("Expense amount cannot be negative. Please try again.")
                    continue

                expenses.append({
                    "name": expense_name,
                    "amount": expense_amount
                })
                print(f"✓ {expense_name}: ${expense_amount:.2f} added")
                break

            except ValueError:
                print("Invalid input. Please enter a valid number.")

    print()
    print("="*50)

    # Step 3: Calculate total expenses
    total_expenses = sum(expense["amount"] for expense in expenses)

    # Step 4: Calculate remaining budget
    remaining_budget = monthly_income - total_expenses

    # Step 5: Display summary
    print("     BUDGET SUMMARY")
    print("="*50)
    print(f"Monthly Income:      ${monthly_income:>10,.2f}")
    print("-" * 50)

    # Display individual expenses
    if expenses:
        print("Expenses:")
        for expense in expenses:
            print(f"  • {expense['name']:<20} ${expense['amount']:>10,.2f}")
        print("-" * 50)

    print(f"Total Expenses:      ${total_expenses:>10,.2f}")
    print("="*50)
    print(f"Remaining Budget:    ${remaining_budget:>10,.2f}")
    print("="*50)

    # Step 6: Display warning if budget is negative
    print()
    if remaining_budget < 0:
        print("⚠️  WARNING: Your budget is negative!")
        print(f"    You are over budget by ${abs(remaining_budget):,.2f}")
    else:
        print("✓ Your budget is balanced!")

    print()

if __name__ == "__main__":
    main()
# Out:
# ...
#      WELCOME TO BUDGET TRACKER
# ...
#
# Enter your monthly income: $1000
#
# Enter your expenses (up to 3):
# --------------------------------------------------
#
# Expense 1 name (or press Enter to skip): home
# Enter amount for home: $600
# ✓ home: $600.00 added
#
# Expense 2 name (or press Enter to skip): skip
# Enter amount for skip: $
# Invalid input. Please enter a valid number.
#
# Expense 2 name (or press Enter to skip):
# Skipping expense 2
#
# Expense 3 name (or press Enter to skip): internet
# Enter amount for internet: $35
# ✓ internet: $35.00 added
#
# ...
#      BUDGET SUMMARY
# ...
# Monthly Income:      $  1,000.00
# --------------------------------------------------
# Expenses:
#   • home                 $    600.00
#   • internet             $     35.00
# --------------------------------------------------
# Total Expenses:      $    635.00
# ...
# Remaining Budget:    $    365.00
# ...
#
# ✓ Your budget is balanced!

# %% [markdown]
# ## Part 4: Enhancement Challenge
#
# Choose ONE feature to add using AI assistance:
# - 🏷️ Expense categories (food, transport, entertainment)
# - 📊 Show percentage of income spent
# - ✅ Input validation (no negative numbers)
# - 📝 Detailed budget summary with advice

# %%
# Document your enhancement
enhancement_choice = "I chose to add: [Show percentage of income spent]"
enhancement_prompt = """
[add a show percentage of income spent code at the top of the result output]
"""

print(f"🚀 ENHANCEMENT: {enhancement_choice}")
# Out:
# 🚀 ENHANCEMENT: I chose to add: [Show percentage of income spent]

# %%
# ENHANCED BUDGET TRACKER
# [# Simple Budget Tracker Program]

def main():
    print("="*50)
    print("     WELCOME TO BUDGET TRACKER")
    print("="*50)
    print()

    # Step 1: Ask for monthly income
    while True:
        try:
            monthly_income = float(input("Enter your monthly income: $"))
            if monthly_income < 0:
                print("Income cannot be negative. Please try again.")
                continue
            break
        except ValueError:
            print("Invalid input. Please enter a valid number.")

    print()

    # Step 2: Ask for up to 3 expenses
    expenses = []
    print("Enter your expenses (up to 3):")
    print("-" * 50)

    for i in range(3):
        while True:
            try:
                expense_name = input(f"\nExpense {i+1} name (or press Enter to skip): ").strip()

                # Allow user to skip entering more expenses
                if expense_name == "":
                    print(f"Skipping expense {i+1}")
                    break

                expense_amount = float(input(f"Enter amount for {expense_name}: $"))

                if expense_amount < 0:
                    print("Expense amount cannot be negative. Please try again.")
                    continue

                expenses.append({
                    "name": expense_name,
                    "amount": expense_amount
                })
                print(f"✓ {expense_name}: ${expense_amount:.2f} added")
                break

            except ValueError:
                print("Invalid input. Please enter a valid number.")

    print()
    print("="*50)

    # Step 3: Calculate total expenses
    total_expenses = sum(expense["amount"] for expense in expenses)

    # Step 4: Calculate remaining budget
    remaining_budget = monthly_income - total_expenses

    # Step 5: Calculate percentage of income spent
    percentage_spent = (total_expenses / monthly_income * 100) if monthly_income > 0 else 0

    # Step 6: Display summary
    print("     BUDGET SUMMARY")
    print("="*50)
    print(f"Percentage of Income Spent: {percentage_spent:>6.2f}%")
    print("="*50)
    print(f"Monthly Income:      ${monthly_income:>10,.2f}")
    print("-" * 50)

    # Display individual expenses
    if expenses:
        print("Expenses:")
        for expense in expenses:
            print(f"  • {expense['name']:<20} ${expense['amount']:>10,.2f}")
        print("-" * 50)

    print(f"Total Expenses:      ${total_expenses:>10,.2f}")
    print("="*50)
    print(f"Remaining Budget:    ${remaining_budget:>10,.2f}")
    print("="*50)

    # Step 7: Display warning if budget is negative
    print()
    if remaining_budget < 0:
        print("⚠️  WARNING: Your budget is negative!")
        print(f"    You are over budget by ${abs(remaining_budget):,.2f}")
    else:
        print("✓ Your budget is balanced!")

    print()

if __name__ == "__main__":
    main()
# Out:
# ...
#      WELCOME TO BUDGET TRACKER
# ...
#
# Enter your monthly income: $5000
#
# Enter your expenses (up to 3):
# --------------------------------------------------
#
# Expense 1 name (or press Enter to skip): house
# Enter amount for house: $1680
# ✓ house: $1680.00 added
#
# Expense 2 name (or press Enter to skip): food
# Enter amount for food: $500
# ✓ food: $500.00 added
#
# Expense 3 name (or press Enter to skip):
# Skipping expense 3
#
# ...
#      BUDGET SUMMARY
# ...
# Percentage of Income Spent:  43.60%
# ...
# Monthly Income:      $  5,000.00
# --------------------------------------------------
# Expenses:
#   • house                $  1,680.00
#   • food                 $    500.00
# --------------------------------------------------
# Total Expenses:      $  2,180.00
# ...
# Remaining Budget:    $  2,820.00
# ...
#
# ✓ Your budget is balanced!

# %% [markdown]
# ## Part 5: Reflection and Lab Exit Ticket Preparation

# %%
# Final Evidence Package Summary
evidence_2 = {
    "timestamp": datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
    "context": "Creating the full budget tracker with enhancements",
    "ai_tool_used": "[Github Copilot]",
    "prompts_used": 3,  # Update this number
    "iterations_needed": 2,  # How many times you refined
    "final_reflection": "[It provide every step that I need]"
}

print("📋 EVIDENCE PACKAGE #2 (Final)")
for key, value in evidence_2.items():
    print(f"{key}: {value}")
# Out:
# 📋 EVIDENCE PACKAGE #2 (Final)
# timestamp: 2026-03-25 11:03:12
# context: Creating the full budget tracker with enhancements
# ai_tool_used: [Github Copilot]
# prompts_used: 3
# iterations_needed: 2
# final_reflection: [It provide every step that I need]

# %% [markdown]
# ## 🎯 Submission Checklist
#
# Before submitting:
# - ✅ All code cells run without errors
# - ✅ You've documented at least 2 AI interactions
# - ✅ Budget tracker accepts income and 3+ expenses
# - ✅ Completed both Evidence Packages
# - ✅ Attempted the enhancement challenge
# - ✅ Reflected on your AI collaboration experience

# %%
# Generate submission summary
print("="*50)
print("WEEK 1 WORKSHEET COMPLETION SUMMARY")
print("="*50)
print(f"Student Name: [Nittayaphon Sangbangmut]")
print(f"Completion Time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print("\nCore Features Implemented:")
print("✅ Basic income/expense input")
print("✅ Budget calculation")
print("✅ Warning for negative budget")
print("✅ Enhancement: [Your enhancement]")
print("\nAI Collaboration Stats:")
print(f"- AI tools used: [GitHub Capilot]")
print(f"- Number of prompts: [3]")
print(f"- Success rate: [100]%")
print("\n🎉 Ready for Lab Exit Ticket submission!")
# Out:
# ...
# WEEK 1 WORKSHEET COMPLETION SUMMARY
# ...
# Student Name: [Nittayaphon Sangbangmut]
# Completion Time: 2026-03-25 11:03:15
#
# Core Features Implemented:
# ✅ Basic income/expense input
# ✅ Budget calculation
# ✅ Warning for negative budget
# ✅ Enhancement: [Your enhancement]
#
# AI Collaboration Stats:
# - AI tools used: [GitHub Capilot]
# - Number of prompts: [3]
# - Success rate: [100]%
#
# 🎉 Ready for Lab Exit Ticket submission!

# %% [markdown]
# ## 💭 Final Reflection Questions
#
# **1. What surprised you most about working with AI to generate code?**
# [It genered correct and fast.]
#
# **2. What makes a good prompt vs. a poor prompt?**
# [A good prompt is clear, detailed, and specific, while a poor prompt is vague and lacks instructions.]
#
# **3. How do you see AI tools fitting into your future programming workflow?**
# [AI tools can help me in my future programming workflow by assisting with writing code, finding errors, and explaining difficult concepts. They can help me work faster and learn new programming skills more easily. I can also use AI to generate ideas, debug problems, and improve my code. However, I still need to understand the code myself so I can check if it works correctly. AI will be a helpful tool, but the programmer still needs to think and make decisions.]
#
# ---
#
# ### 📁 Save and Next Steps:
# 1. File > Save a copy in GitHub (if you haven't already)
# 2. Prepare evidence for next lab session for the Exit Ticket
# 3. Start thinking about Week 2: Variables & Data Types!
