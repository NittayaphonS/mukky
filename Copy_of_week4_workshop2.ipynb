# %% [markdown]
# <a href="https://colab.research.google.com/github/NittayaphonS/mukky/blob/main/Copy_of_week4_workshop2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 4 Workshop 2: Lists and Data Processing
# ## Turning Your Finance Tracker Into a Data Powerhouse
#
# **Duration:** 45 minutes
# **Goal:** Master lists and collection processing to analyze financial data patterns
#
# ### What You'll Build
# Transform your loop-powered tracker from Workshop 1 into a smart analysis system:
# - ✅ Store complete transaction histories
# - ✅ Search and filter transactions
# - ✅ Calculate spending patterns and insights
# - ✅ Interactive menu system for ongoing use
# - ✅ Foundation for AI-powered features next week
#
# ---

# %% [markdown]
# ## Part 1: From Variables to Collections (8 minutes)
#
# ### 🧠 The Collection Problem
#
# Your Workshop 1 tracker can handle multiple expenses, but it can't remember them for analysis. Let's fix that!

# %%
# Problem: Workshop 1 approach - data gets lost
print("=== Workshop 1 Limitation Demo ===")

total = 0
count = 0

# Simulating Workshop 1 approach
for i in range(3):  # Pretend we got 3 expenses
    expense = (i + 1) * 25  # 25, 50, 75
    total += expense
    count += 1
    print(f"Expense {i+1}: ${expense}")

print(f"\nTotal: ${total}, Count: {count}")
print("\n❌ Problem: Individual expenses are LOST!")
print("❌ Can't find largest expense")
print("❌ Can't categorize by amount")
print("❌ Can't search transaction history")

# %%
# Solution: Store in collections for later analysis
print("=== Collection-Powered Solution ===")

expenses = []       # Store amounts
descriptions = []   # Store what each expense was for
total = 0

# Collect the same data but REMEMBER everything
for i in range(3):
    expense = (i + 1) * 25  # 25, 50, 75
    description = f"Item {i+1}"

    expenses.append(expense)
    descriptions.append(description)
    total += expense

print(f"All expenses: {expenses}")
print(f"All descriptions: {descriptions}")

print("\n✅ Now we can analyze patterns!")
print(f"✅ Largest expense: ${max(expenses)}")
print(f"✅ Smallest expense: ${min(expenses)}")
print(f"✅ Average expense: ${total/len(expenses):.2f}")

# Count expensive items
expensive_count = 0
for expense in expenses:
    if expense > 40:  # Arbitrary threshold
        expensive_count += 1

print(f"✅ Expensive items (>$40): {expensive_count}")

# %% [markdown]
# ### 🎯 Your Understanding Check
#
# **Complete this analogy:**
# - Variables are like individual sticky notes
# - Lists are like ________________
#
# Write your answer and reasoning as comments below:

# %%
# Your analogy completion:
# Lists are like __stores___________ because ___they hold many items__________

# Why does this matter for your finance tracker?
# Using lists allows your finance tracker to store multiple expenses, budgets, or income entries
# for different days or categories. Instead of creating a separate variable for each expense,
# you can keep them all in a list and loop through them to calculate totals, averages, or summaries.

# %% [markdown]
# ---
#
# ## Part 2: List Indexing and Safe Access (7 minutes)
#
# ### 🔢 Understanding the Index System
#
# Lists use numbered positions starting from 0. This trips up everyone initially!

# %%
# Visual demonstration of indexing
monthly_expenses = [450.00, 380.50, 520.25, 290.75]

print("Your monthly expenses:")
print(f"List: {monthly_expenses}")
print(f"Index positions: 0, 1, 2, 3")
print()

print("Accessing by index:")
print(f"First month (index 0): ${monthly_expenses[0]}")
print(f"Second month (index 1): ${monthly_expenses[1]}")
print(f"Last month (index -1): ${monthly_expenses[-1]}")
print(f"Total months: {len(monthly_expenses)}")

print("\n🚨 Common mistake:")
try:
    print(f"Month 4 (index 4): ${monthly_expenses[4]}")
except IndexError as e:
    print(f"IndexError: {e}")
    print("Remember: 4 items have indices 0,1,2,3 (not 1,2,3,4)")
# Out:
# Your monthly expenses:
# List: [450.0, 380.5, 520.25, 290.75]
# Index positions: 0, 1, 2, 3
#
# Accessing by index:
# First month (index 0): $450.0
# Second month (index 1): $380.5
# Last month (index -1): $290.75
# Total months: 4
#
# 🚨 Common mistake:
# IndexError: list index out of range
# Remember: 4 items have indices 0,1,2,3 (not 1,2,3,4)

# %% [markdown]
# ### 🛡️ Safe List Access Patterns
#
# Always check before accessing to prevent crashes:

# %%
# Your Challenge: Safe transaction display
transactions = []  # Start with empty list

# Add some sample transactions
transactions.append(25.50)
transactions.append(67.25)
transactions.append(15.00)

print("=== Safe Transaction Display ===")

# Your task: Complete this safe access pattern
if len(transactions) > 0:  # Check if list has items
    print(f"First transaction: ${transactions[0]}")
    print(f"Latest transaction: ${transactions[-1]}")
    print(f"Total transactions: {len(transactions)}")

    # Show all transactions safely
    print("\nAll transactions:")
    # Your for loop here - display each with position number
for i, amount in enumerate(transactions, start=1):  # start=1 to number from 1
    print(f"{i}. ${amount}")
else:
    print("No transactions recorded yet")

# Test with empty list
empty_list = []
print(f"\nEmpty list test: {len(empty_list)} items")
if len(empty_list) > 0:
    print(f"First: {empty_list[0]}")
else:
    print("✅ Safely handled empty list!")
# Out:
# === Safe Transaction Display ===
# First transaction: $25.5
# Latest transaction: $15.0
# Total transactions: 3
#
# All transactions:
# 1. $25.5
# 2. $67.25
# 3. $15.0
# No transactions recorded yet
#
# Empty list test: 0 items
# ✅ Safely handled empty list!

# %% [markdown]
# ---
#
# ## Part 3: Collection Processing Patterns (12 minutes)
#
# ### 📊 Financial Data Analysis Patterns
#
# Now that you can store transaction data, let's analyze it! These patterns work for ANY collection analysis.

# %%
# Sample transaction data for analysis practice
expenses = [23.50, 156.75, 45.00, 89.25, 12.80, 234.60, 67.30]
categories = ["Food", "Rent", "Food", "Gas", "Food", "Rent", "Entertainment"]

print("=== Financial Analysis Patterns ===")
print(f"Sample data: {len(expenses)} transactions")
print()

# Pattern 1: Accumulation (Sum/Average)
total = 0
for expense in expenses:
    total += expense

average = total / len(expenses)
print(f"📈 Total spent: ${total:.2f}")
print(f"📊 Average per transaction: ${average:.2f}")

# Pattern 2: Conditional Counting
large_expenses = 0
large_threshold = 100

for expense in expenses:
    if expense > large_threshold:
        large_expenses += 1

print(f"🔍 Large expenses (>${large_threshold}): {large_expenses}")

# Pattern 3: Finding Extremes
if len(expenses) > 0:
    highest = expenses[0]  # Start with first item
    lowest = expenses[0]

    for expense in expenses:
        if expense > highest:
            highest = expense
        if expense < lowest:
            lowest = expense

    print(f"💰 Highest expense: ${highest}")
    print(f"💸 Lowest expense: ${lowest}")
    print(f"📏 Spending range: ${highest - lowest:.2f}")
# Out:
# === Financial Analysis Patterns ===
# Sample data: 7 transactions
#
# 📈 Total spent: $629.20
# 📊 Average per transaction: $89.89
# 🔍 Large expenses (>$100): 2
# 💰 Highest expense: $234.6
# 💸 Lowest expense: $12.8
# 📏 Spending range: $221.80

# %% [markdown]
# ### 🎯 Your Challenge: Category Analysis
#
# Use the sample data above to analyze spending by category. Complete each pattern:

# %%
# Given data (same as above)
expenses = [23.50, 156.75, 45.00, 89.25, 12.80, 234.60, 67.30]
categories = ["Food", "Rent", "Food", "Gas", "Food", "Rent", "Entertainment"]

print("=== Category Analysis Challenge ===")

# Challenge 1: Count transactions per category
food_count = 0
rent_count = 0
# Your counting code here
# Hint: Loop through categories list and count each type
for category in categories:
    if category == "Food":
        food_count += 1
    elif category == "Rent":
        rent_count += 1

# Challenge 2: Sum spending per category
food_total = 0
rent_total = 0
# Your summation code here
# Hint: Need to use index to match expense[i] with category[i]
for i in range(len(expenses)):
    if categories[i] == "Food":
        food_total += expenses[i]
    elif categories[i] == "Rent":
        rent_total += expenses[i]


# Challenge 3: Find most expensive transaction in each category
# Your max-finding code here
# Hint: Track highest food expense and highest rent expense separately
max_food = 0
max_rent = 0

for i in range(len(expenses)):
    if categories[i] == "Food" and expenses[i] > max_food:
        max_food = expenses[i]
    elif categories[i] == "Rent" and expenses[i] > max_rent:
        max_rent = expenses[i]


print("\n📊 Category Summary:")
print(f"Food: {food_count} transactions, ${food_total:.2f} total")
print(f"Rent: {rent_count} transactions, ${rent_total:.2f} total")
# Add your other category results
# Out:
# === Category Analysis Challenge ===
#
# 📊 Category Summary:
# Food: 3 transactions, $81.30 total
# Rent: 2 transactions, $391.35 total

# %% [markdown]
# ### 🤝 AI Checkpoint 1: Pattern Recognition
#
# After completing the category analysis, ask AI:
#
# ```
# "I just wrote code to analyze expenses by category using loops and lists.
# Here's my approach:
# [paste your code]
#
# 1. What data processing patterns am I using?
# a) Accumulation (Sum)
# Example: food_total += expenses[i]
# Pattern: Loop through a list and add values that meet a condition.
# Why useful: Computes totals per category, total spending, or averages.
# b) Conditional Counting
# Example: food_count += 1 if category == "Food"
# Pattern: Loop through a list and increment a counter when a condition is true.
# Why useful: Counts the number of transactions per category, number of large expenses, etc.
# c) Finding Extremes
# Example: if expenses[i] > max_food: max_food = expenses[i]
# Pattern: Loop through a list and track the maximum or minimum.
# Why useful: Identifies the highest or lowest expense in a category, or overall extremes.
#
# 2. Is there a more efficient way to match expenses with categories?
# - Pattern insight: You’re essentially doing a pairwise traversal, matching expenses[i] with categories[i].
#
# - A more readable approach (still using loops) is zipping the list.
#
# 3. What other financial insights could I calculate with these same patterns?
#
# - Once you understand these three basic patterns, you can apply them to almost any financial summary: totals, counts, extremes, averages, percentages, thresholds… the logic stays the same, only the condition or accumulation changes.
#
# Help me understand the patterns, don't just give me different code."
# ```
#
# ---

# %% [markdown]
# ## Part 2: Search and Filter Patterns (10 minutes)
#
# ### 🔍 Finding Specific Transactions
#
# Real finance trackers need search capabilities. Let's build the fundamental patterns:

# %%
# Sample transaction database
amounts = [23.50, 156.75, 45.00, 89.25, 12.80, 234.60, 67.30]
descriptions = ["Grocery", "Rent", "Restaurant", "Gas", "Coffee", "Rent", "Movie"]
dates = ["Jan 1", "Jan 1", "Jan 2", "Jan 3", "Jan 3", "Feb 1", "Feb 5"]

print("=== Transaction Search Demo ===")

# Pattern 1: Search by description
search_term = "Rent"
found_transactions = []

print(f"Searching for transactions containing '{search_term}':")

for i in range(len(descriptions)):
    if search_term.lower() in descriptions[i].lower():
        # Found a match! Store the complete transaction info
        transaction_info = {
            'amount': amounts[i],
            'description': descriptions[i],
            'date': dates[i]
        }
        found_transactions.append(transaction_info)
        print(f"  📝 {dates[i]}: ${amounts[i]} - {descriptions[i]}")

print(f"\nFound {len(found_transactions)} matching transactions")

# Calculate total for search results
search_total = 0
for transaction in found_transactions:
    search_total += transaction['amount']

print(f"Total for '{search_term}': ${search_total:.2f}")
# Out:
# === Transaction Search Demo ===
# Searching for transactions containing 'Rent':
#   📝 Jan 1: $156.75 - Rent
#   📝 Feb 1: $234.6 - Rent
#
# Found 2 matching transactions
# Total for 'Rent': $391.35

# %% [markdown]
# ### 🎯 Your Challenge: Amount-Based Filtering
#
# Build a filter that finds all transactions within a specific amount range:

# %%
# Use the same sample data
amounts = [23.50, 156.75, 45.00, 89.25, 12.80, 234.60, 67.30]
descriptions = ["Grocery", "Rent", "Restaurant", "Gas", "Coffee", "Rent", "Movie"]

print("=== Amount Range Filter ===")

# Get filter criteria
min_amount = float(input("Minimum amount: $"))
max_amount = float(input("Maximum amount: $"))

print(f"\nFinding transactions between ${min_amount} and ${max_amount}:")

# Your filtering code here:
# 1. Loop through the amounts list
# 2. Check if each amount is in range
# 3. If yes, display the transaction info
# 4. Count and sum the matching transactions

matching_count = 0
matching_total = 0

# Your loop here
for i in range(len(amounts)):
    if min_amount <= amounts[i] <= max_amount:  # Check if amount is in range
        print(f"  📝 ${amounts[i]} - {descriptions[i]}")  # Display transaction info
        matching_count += 1      # Count matching transaction
        matching_total += amounts[i]  # Add to total

print(f"\n📊 Filter Results:")
print(f"Matching transactions: {matching_count}")
print(f"Total in range: ${matching_total:.2f}")
# Out:
# === Amount Range Filter ===
# Minimum amount: $12.8
# Maximum amount: $234.6
#
# Finding transactions between $12.8 and $234.6:
#   📝 $23.5 - Grocery
#   📝 $156.75 - Rent
#   📝 $45.0 - Restaurant
#   📝 $89.25 - Gas
#   📝 $12.8 - Coffee
#   📝 $234.6 - Rent
#   📝 $67.3 - Movie
#
# 📊 Filter Results:
# Matching transactions: 7
# Total in range: $629.20

# %% [markdown]
# ### 🔍 Advanced Search Challenge
#
# Create a search that finds transactions by date AND amount criteria:

# %%
# Multi-criteria search challenge
amounts = [23.50, 156.75, 45.00, 89.25, 12.80, 234.60, 67.30]
descriptions = ["Grocery", "Rent", "Restaurant", "Gas", "Coffee", "Rent", "Movie"]
dates = ["Jan 1", "Jan 1", "Jan 2", "Jan 3", "Jan 3", "Feb 1", "Feb 5"]

print("=== Advanced Search: January Expenses Over $20 ===")

# Your search logic here:
# Find all transactions that are:
# 1. From January (date contains "Jan")
# 2. Amount greater than $20

# Pattern: AND condition in if statement
# for i in range(len(dates)):
#     if (condition1) and (condition2):
#         # Process matching transaction
# Multi-criteria search: January transactions over $20
matching_count = 0
matching_total = 0

for i in range(len(dates)):
    if "Jan" in dates[i] and amounts[i] > 20:  # AND condition
        print(f"  📝 {dates[i]}: ${amounts[i]} - {descriptions[i]}")
        matching_count += 1
        matching_total += amounts[i]

print(f"\n📊 Search Results:")
print(f"Matching transactions: {matching_count}")
print(f"Total amount: ${matching_total:.2f}")
# Out:
# === Advanced Search: January Expenses Over $20 ===
#   📝 Jan 1: $23.5 - Grocery
#   📝 Jan 1: $156.75 - Rent
#   📝 Jan 2: $45.0 - Restaurant
#   📝 Jan 3: $89.25 - Gas
#
# 📊 Search Results:
# Matching transactions: 4
# Total amount: $314.50

# %% [markdown]
# ---
#
# ## Part 3: Interactive Menu Systems (15 minutes)
#
# ### 🎮 Building User-Controlled Programs
#
# Combine everything you've learned into an interactive finance tracker that keeps running until the user decides to quit:

# %%
print("=== Interactive Finance Tracker v0.3 ===")
print("Workshop 2: Lists + Loops = Power!")
print()

# Initialize tracker data
name = input("Enter your name: ")
expenses = []        # Store all expense amounts
descriptions = []    # Store what each expense was for
budget = 0

# Get budget with validation (your Workshop 1 pattern)
while budget < 100 or budget > 50000:
    try:
        budget_str = input("Monthly budget ($100-$50,000): $")
        budget = float(budget_str)
        if budget < 100:
            print("Budget too low! Minimum $100")
        elif budget > 50000:
            print("Budget too high! Maximum $50,000")
    except ValueError:
        print("Please enter a valid number!")
        budget = 0

print(f"\nWelcome {name}! Budget: ${budget:.2f}")

# Main program loop
running = True

while running:
    # Display menu
    print("\n" + "="*40)
    print(f"💰 {name}'s Finance Tracker")
    # Check if expenses is not empty before sum() to avoid error if no expenses yet
    current_spent = sum(expenses) if expenses else 0
    print(f"📊 Current: {len(expenses)} transactions, ${current_spent:.2f} spent")
    print("="*40)
    print("1. Add expense")
    print("2. View all transactions")
    print("3. Search transactions")
    print("4. Budget analysis")
    print("5. Exit")

    choice = input("\nChoose option (1-5): ")

    if choice == "1":
        print("\n--- Add Expense ---")
        amount = 0
        while amount <= 0:
            try:
                amount = float(input("Expense amount: $"))
                if amount <= 0:
                    print("Amount must be greater than 0!")
            except ValueError:
                print("Enter a valid number!")

        description = input("Description: ")

        # Add to lists
        expenses.append(amount)
        descriptions.append(description)

        # Feedback: percentage of budget used
        # Check to avoid ZeroDivisionError if budget is 0 (though budget validation prevents this, good practice)
        if budget > 0:
            percent_used = sum(expenses) / budget * 100
            print(f"Added: ${amount:.2f} for {description}")
            print(f"Budget used: {percent_used:.1f}%")
        else:
            print(f"Added: ${amount:.2f} for {description}")

    elif choice == "2":
        # View all transactions
        print("\n--- Transaction History ---")
        if len(expenses) == 0:
            print("No transactions yet!")
        else:
            # Your display code here
            # Show each transaction with number, amount, description
            for i, (amount, desc) in enumerate(zip(expenses, descriptions), start=1):
                print(f"{i}. ${amount:.2f} - {desc}")

    elif choice == "3":
        print("\n--- Search Transactions ---")
        if not expenses:
            print("No transactions to search!")
        else:
            term = input("Enter search term: ").lower()

            found = []
            for amount, desc in zip(expenses, descriptions):
                if term in desc.lower():
                    found.append((amount, desc))

            if found:
                for i, (amount, desc) in enumerate(found, start=1):
                    print(f"{i}. ${amount:.2f} - {desc}")
                total = sum(amount for amount, _ in found)
                print(f"Total of matching transactions: ${total:.2f}")
            else:
                print("No matching transactions found!")

    elif choice == "4":
        print("\n--- Budget Analysis ---")
        if len(expenses) == 0:
            print("No expenses recorded yet for analysis.")
        else:
            total_spent = sum(expenses)
            average = total_spent / len(expenses)
            percent_used = total_spent / budget * 100
            large_expenses = sum(1 for e in expenses if e > budget * 0.1)
            small_expenses = len(expenses) - large_expenses
            highest = max(expenses)
            lowest = min(expenses)

            print(f"Total spent: ${total_spent:.2f}")
            print(f"Average per transaction: ${average:.2f}")
            print(f"Budget used: {percent_used:.1f}%")
            print(f"Large expenses (>10% of budget): {large_expenses}")
            print(f"Small expenses: {small_expenses}")
            print(f"Highest: ${highest:.2f}, Lowest: ${lowest:.2f}")

            if percent_used > 90:
                print("⚠️ You are close to your budget limit!")
            elif percent_used < 50:
                print("👍 Budget under control!")

    elif choice == "5": # This was previously `elif choice == "5":` and then `elif choice == "5":` again.
        # Exit
        running = False
        print(f"\nGoodbye {name}! Your financial future is bright! 🌟")

    else:
        print("Invalid choice! Please choose 1-5.")

print("\n🎯 Finance Tracker session complete!")
# Out:
# === Interactive Finance Tracker v0.3 ===
# Workshop 2: Lists + Loops = Power!
#
# Enter your name: Mukky
# Monthly budget ($100-$50,000): $5600
#
# Welcome Mukky! Budget: $5600.00
#
# ========================================
# 💰 Mukky's Finance Tracker
# 📊 Current: 0 transactions, $0.00 spent
# ========================================
# 1. Add expense
# 2. View all transactions
# 3. Search transactions
# 4. Budget analysis
# 5. Exit
#
# Choose option (1-5): 1
#
# --- Add Expense ---
# Expense amount: $500
# Description: food
# Added: $500.00 for food
# Budget used: 8.9%
#
# ========================================
# 💰 Mukky's Finance Tracker
# 📊 Current: 1 transactions, $500.00 spent
# ========================================
# 1. Add expense
# 2. View all transactions
# 3. Search transactions
# 4. Budget analysis
# 5. Exit
#
# Choose option (1-5): 2
#
# --- Transaction History ---
# 1. $500.00 - food
#
# ========================================
# 💰 Mukky's Finance Tracker
# 📊 Current: 1 transactions, $500.00 spent
# ========================================
# 1. Add expense
# 2. View all transactions
# 3. Search transactions
# 4. Budget analysis
# 5. Exit
#
# Choose option (1-5): 3
#
# --- Search Transactions ---
# Enter search term: Food
# 1. $500.00 - food
# Total of matching transactions: $500.00
#
# ========================================
# 💰 Mukky's Finance Tracker
# 📊 Current: 1 transactions, $500.00 spent
# ========================================
# 1. Add expense
# 2. View all transactions
# 3. Search transactions
# 4. Budget analysis
# 5. Exit
#
# Choose option (1-5): 4
#
# --- Budget Analysis ---
# Total spent: $500.00
# Average per transaction: $500.00
# Budget used: 8.9%
# Large expenses (>10% of budget): 0
# Small expenses: 1
# Highest: $500.00, Lowest: $500.00
# 👍 Budget under control!
#
# ========================================
# 💰 Mukky's Finance Tracker
# 📊 Current: 1 transactions, $500.00 spent
# ========================================
# 1. Add expense
# 2. View all transactions
# 3. Search transactions
# 4. Budget analysis
# 5. Exit
#
# Choose option (1-5): 5
#
# Goodbye Mukky! Your financial future is bright! 🌟
#
# 🎯 Finance Tracker session complete!

# %% [markdown]
# ### 💡 Implementation Strategy
#
# **Complete the menu system step by step:**
#
# 1. **Start with Option 1** (Add expense) - use your Workshop 1 validation pattern
# 2. **Then Option 2** (View all) - use safe list access pattern
# 3. **Then Option 4** (Analysis) - use accumulation and counting patterns
# 4. **Finally Option 3** (Search) - use search pattern from Part 2
#
# **Test after each option works!**

# %% [markdown]
# ---
#
# ## Part 4: Advanced Pattern Application (8 minutes)
#
# ### 📈 Spending Trend Analysis
#
# Let's build more sophisticated analysis using the patterns you've mastered:

# %%
# Advanced Challenge: Spending Trends
print("=== Spending Pattern Analyzer ===")

# Simulated weekly spending data
weekly_totals = [156.75, 234.50, 198.25, 267.80, 145.60]
week_names = ["Week 1", "Week 2", "Week 3", "Week 4", "Week 5"]

print("Weekly spending analysis:")

# Challenge 1: Show each week with trend indicator
for i in range(len(weekly_totals)):
    current_week = weekly_totals[i]

    # Compare with previous week (if not first week)
    if i > 0:
        previous_week = weekly_totals[i-1]

        # Your trend logic here:
        # If current > previous: "📈 Up"
        # If current < previous: "📉 Down"
        # If current == previous: "➡️ Same"
        if current_week > previous_week:
            trend = "📈 Up"
        elif current_week < previous_week:
            trend = "📉 Down"
        else:
            trend = "➡️ Same"
        # Calculate percentage change
        # change_percent = ((current - previous) / previous) * 100
        change_percent = ((current_week - previous_week) / previous_week) * 100

        print(f"{week_names[i]}: ${current_week:.2f}, {change_percent:.1f}%]")
    else:
        print(f"{week_names[i]}: ${current_week:.2f} [Baseline]")

# Challenge 2: Find best and worst spending weeks
# Your min/max pattern here
min_index = weekly_totals.index(min(weekly_totals))
max_index = weekly_totals.index(max(weekly_totals))

print(f"\n💰 Best spending week (lowest): {week_names[min_index]} - ${weekly_totals[min_index]:.2f}")
print(f"💸 Worst spending week (highest): {week_names[max_index]} - ${weekly_totals[max_index]:.2f}")
# Challenge 3: Calculate if spending is trending up or down overall
# Compare first week to last week
overall_change = weekly_totals[-1] - weekly_totals[0]
overall_percent = (overall_change / weekly_totals[0]) * 100

if overall_change > 0:
    overall_trend = "📈 Increasing overall"
elif overall_change < 0:
    overall_trend = "📉 Decreasing overall"
else:
    overall_trend = "➡️ Stable overall"

print(f"\n📊 Overall trend: {overall_trend} ({overall_percent:.1f}%)")
# Out:
# === Spending Pattern Analyzer ===
# Weekly spending analysis:
# Week 1: $156.75 [Baseline]
# Week 2: $234.50, 49.6%]
# Week 3: $198.25, -15.5%]
# Week 4: $267.80, 35.1%]
# Week 5: $145.60, -45.6%]
#
# 💰 Best spending week (lowest): Week 5 - $145.60
# 💸 Worst spending week (highest): Week 4 - $267.80
#
# 📊 Overall trend: 📉 Decreasing overall (-7.1%)

# %% [markdown]
# ### 🎯 Your Innovation Challenge
#
# Design a new financial insight using list processing patterns. Ideas:
# - Find the most common expense amount range
# - Detect unusual spending spikes
# - Calculate "spending consistency" score
# - Identify expense categories trending up/down
#
# **Pick one and implement it:**

# %%
# Your innovative financial insight here
print("=== My Financial Insight Innovation ===")

# Sample data to work with
expenses = [23.50, 156.75, 45.00, 89.25, 12.80, 234.60, 67.30, 45.00, 89.25]
descriptions = ["Grocery", "Rent", "Restaurant", "Gas", "Coffee", "Rent", "Movie", "Grocery", "Gas"]

# Your innovation here - what insight will you calculate?
# Describe your approach:
print("My insight:I want to find which category (description) I spend the most money on overall and how much it contributes to total spending.")


# Your implementation:
# 1. Create a dictionary to sum expenses per category
category_totals = {}

for amount, desc in zip(expenses, descriptions):
    if desc in category_totals:
        category_totals[desc] += amount
    else:
        category_totals[desc] = amount

# 2. Find the category with the maximum spending
max_category = max(category_totals, key=category_totals.get)
max_amount = category_totals[max_category]

# 3. Calculate total spending
total_spent = sum(expenses)
percent_of_total = (max_amount / total_spent) * 100

# 4. Display results
print("\n💡 Financial Insight:")
print(f"Category with highest spending: {max_category} - ${max_amount:.2f}")
print(f"This is {percent_of_total:.1f}% of total expenses (${total_spent:.2f})")
# Out:
# === My Financial Insight Innovation ===
# My insight:I want to find which category (description) I spend the most money on overall and how much it contributes to total spending.
#
# 💡 Financial Insight:
# Category with highest spending: Rent - $391.35
# This is 51.3% of total expenses ($763.45)

# %% [markdown]
# ---
#
# ## Part 5: Integration and Testing (5 minutes)
#
# ### 🧪 Complete System Test
#
# Test your completed interactive finance tracker with realistic data:

# %%
# Test scenario - run your complete interactive tracker with this data:
test_scenario = """
Test your interactive finance tracker with:

Setup:
- Name: Your actual name
- Budget: $2000

Add these expenses:
- $450 for "Rent"
- $67.50 for "Groceries"
- $23.75 for "Coffee"
- $89.00 for "Gas"
- done

Then test each menu option:
- View all transactions
- Search for "Rent"
- Run budget analysis
- Exit

Expected results:
- 4 transactions totaling $630.25
- 31.5% of budget used
- $1369.75 remaining
- 1 large expense (rent)
"""

print(test_scenario)
print("\nRun your interactive tracker above with this test data! ⬆️")
# Out:
# Test your interactive finance tracker with:
#
# Setup:
# - Name: Your actual name
# - Budget: $2000
#
# Add these expenses:
# - $450 for "Rent"
# - $67.50 for "Groceries"
# - $23.75 for "Coffee"
# - $89.00 for "Gas"
# - done
#
# Then test each menu option:
# - View all transactions
# - Search for "Rent"
# - Run budget analysis
# - Exit
#
# Expected results:
# - 4 transactions totaling $630.25
# - 31.5% of budget used
# - $1369.75 remaining
# - 1 large expense (rent)
#
#
# Run your interactive tracker above with this test data! ⬆️

# %% [markdown]
# ### 🤝 AI Checkpoint 2: System Review
#
# After testing your complete system, ask AI:
#
# ```
# "I've built an interactive finance tracker that uses:
# - While loops for input validation
# - Sentinel values for expense collection
# - For loops for transaction analysis
# - Lists to store transaction history
# - Menu system for user interaction
#
# Here's my complete code:
# [paste your interactive tracker]
#
# 1. What programming patterns am I using successfully?
# ANS:
# 1)Input Validation with While Loops
# Example: budget input and expense amounts.
# Pattern: repeatedly ask until input is valid → prevents errors.
# ✅ This is critical for reliable user-driven programs.
# 2)Sentinel Values / Conditional Loops
# The running = True loop with menu choices acts as a sentinel-controlled loop.
# Pattern: keeps program running until a user explicitly decides to exit.
# 3)For Loops for Analysis
# Used for:
# Displaying all transactions (for i, (amount, desc) in enumerate(zip(...)))
# Searching transactions
# Summing totals or calculating averages
# Pattern: iterating over lists in parallel (zip) → classic for data processing.
# 4)Lists for Data Storage
# Separate lists for expenses and descriptions.
# Pattern: lists allow accumulation, indexing, and matching of related data.
# Example: expenses[i] corresponds to descriptions[i] → foundational for structured data.
# 5)Menu System for User Interaction
# Pattern: modular design with menu-driven options → makes program interactive and expandable.
# Each option encapsulates a specific pattern (add, view, search, analyze, exit).
# 6)Conditional Logic
# Pattern: if/elif/else for menu choice handling and trend detection.
# Also used for validation and analysis thresholds (large vs small expenses).
#
#
# 2. Are there any edge cases I should test?
# ANS:
# 1)Empty Transactions
# Viewing, searching, or analyzing when no expenses exist → should handle gracefully.
# 2)Zero or Negative Expense
# User might accidentally input $0 or -50. Validation must catch this.
# 3)Non-numeric Input
# Budget or expense inputs like "abc" → already handled with try/except.
# 4)Budget Smaller than Expenses
# Test if program calculates percent_used correctly when total spending exceeds budget.
# 5)Case Sensitivity in Search
# Searching "rent" vs "Rent" → your .lower() logic handles it, but worth testing.
# 6)Duplicate Transactions
# Program should still handle repeated transactions correctly in analysis.
#
# 3. What features would make this more useful for real budget tracking?
# ANS:
# 1)Category Tracking
# Instead of just description, add a category field (Food, Rent, Transport) to summarize spending.
# 2)Date Tracking
# Add dates to track weekly/monthly patterns → allows trends and forecasting.
# 3)Export/Save History
# Save transactions to a file (CSV/JSON) → so users can keep long-term records.
# 4)Budget Alerts
# Warn if spending exceeds a percentage of budget or a category limit.
# 5)Trend Analysis
# Show week-over-week or month-over-month trends like your spending pattern analyzer.
#
# 4. How does this prepare me for adding AI features later?
# ANS:
# 1)Structured Data
# You already use lists of related data. This is foundational for AI because models need structured input (amount, description, date, category).
# 2)User Interaction Loops
# Your menu system mirrors a chatbot-style interface → easy to expand to AI-driven suggestions.
# 3)Data Aggregation Patterns
# Accumulation, counting, searching → you’re already doing basic data analysis.
# AI can build on these patterns to predict spending, detect anomalies, or recommend savings.
# 4)Conditional Logic
# Threshold-based advice (budget warnings) can be replaced or augmented with AI that learns thresholds dynamically.
# 5)Extensibility
# Your modular option-based design makes it easy to add new features, like an AI assistant suggesting ways to reduce high spending categories.
#
# Focus on helping me understand what I've built, not just suggesting changes."
# ```
#
# ---

# %% [markdown]
# ## Part 6: Computational Thinking Reflection (5 minutes)
#
# ### 🧠 Meta-Learning: Understanding Your Learning
#
# Complete these reflections about your computational thinking development:

# %%
# Computational thinking reflection (write as comments)

# PATTERN RECOGNITION:
# I noticed that the input-validation while loops from Workshop 1 (asking repeatedly until the user enters a valid number)
# could be reused in Workshop 2 for both budget input and expense amounts.
# The for-loops for iterating through lists of transactions to sum totals, search, or display items were also a pattern I reused.

# DECOMPOSITION:
# I broke the interactive finance tracker into smaller problems:
# 1. Gathering valid user input for budget and expenses.
# 2. Storing expenses and descriptions in separate lists.
# 3. Displaying transaction history in a readable format.
# 4. Searching transactions by keyword.
# 5. Performing budget analysis (totals, averages, large vs small expenses).
# Each menu option became a separate “mini-task” I could implement and test individually.

# ABSTRACTION:
# The patterns I used — validating inputs, storing parallel lists, summing or searching data, calculating averages and percentages —
# could work for other types of data:
# - Grade tracking: store scores and subjects, calculate averages and find highest/lowest scores.
# - Inventory management: store quantities and item names, sum stock, search for items.
# - Habit tracking: store daily habits and notes, analyze frequency or streaks.

# ALGORITHM DESIGN:
# My planning has improved: I now think of each feature as a step-by-step process before coding.
# For example, before adding an expense, I plan to:
# 1. Ask for amount and validate it.
# 2. Ask for description.
# 3. Store both in lists.
# 4. Calculate updated totals and percentages.
# This systematic approach reduces errors and makes my code easier to extend.

# AI PARTNERSHIP:
# In Workshop 1, I mostly asked AI for syntax or simple code snippets.
# In Workshop 2, I started asking AI to help me:
# - Understand programming patterns I was already using.
# - Suggest edge cases or ways to make the tracker more robust.
# - Explain the reasoning behind loops, lists, and menu systems.
# This helped me think critically about *why* my code works, not just *how*.

print("🎯 Workshop 2 reflection complete!")
print("Ready for the mini-project challenge! 🚀")
# Out:
# 🎯 Workshop 2 reflection complete!
# Ready for the mini-project challenge! 🚀

# %% [markdown]
# ---
#
# ## 🚀 Workshop 2 Complete!
#
# ### **What You've Mastered:**
# - ✅ **List Storage**: Keeping transaction history for analysis
# - ✅ **Safe Access**: Preventing index errors with proper bounds checking
# - ✅ **Search Patterns**: Finding specific transactions by various criteria
# - ✅ **Analysis Patterns**: Accumulation, counting, and extremes
# - ✅ **Menu Systems**: Interactive programs that keep running
# - ✅ **Integration**: Combining multiple loop patterns effectively
#
# ### **Your Finance Tracker Evolution:**
# - **Week 1**: Basic calculations and logic
# - **Week 2**: Smart decision making
# - **Week 3 Workshop 1**: Loop-powered input and validation
# - **Week 3 Workshop 2**: Data storage and pattern analysis
# - **Coming**: AI-powered insights and recommendations
#
# ### **🎯 Mini-Project Preview:**
# In the mini-project, you'll use these patterns to build advanced finance features:
# - Monthly spending category breakdown
# - Savings goal progress tracking with multiple goals
# - Spending habit pattern detection
# - Budget optimization recommendations
#
# ### **💡 Key Insight:**
# You now have the core patterns that power ALL data processing:
# - **Accumulation** (totals, averages)
# - **Filtering** (search, conditions)
# - **Counting** (categories, frequencies)
# - **Extremes** (min, max, ranges)
#
# These patterns work for financial data, student grades, sales records, sensor data - ANY collection!
#
# ### **🤖 AI Partnership Growth:**
# Notice how your AI interactions evolved:
# - Week 1: "How do I...?"
# - Workshop 1: "Should I use while or for?"
# - Workshop 2: "What patterns am I using?"
# - **Next**: "How can AI enhance these patterns?"
#
# ---
#
# **Ready for the mini-project? Your finance tracker is about to get seriously smart! 💰🤖**
